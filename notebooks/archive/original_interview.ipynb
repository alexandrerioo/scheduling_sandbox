# %% [markdown]
# # **Import des librairies**

# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt

# %% [markdown]
# #**Jeu de données**

# %%
url_articles = 'https://gitlab.com/boris112/data-interviews/-/raw/main/sample_data/articles.csv'
articles = pd.read_csv(url_articles)
url_clients = 'https://gitlab.com/boris112/data-interviews/-/raw/main/sample_data/clients.csv'
clients = pd.read_csv(url_clients)

# %% [markdown]
# # **Data engineering**

# %% [markdown]
# 1) Effectuer une jointure entre les dataframes articles et clients

# %% [markdown]
# 2) Filtrer pour ne plus avoir les clients "client3" et "client4"

# %% [markdown]
# # **Modélisation**
#
#
# Proposer un plan d'action pour modéliser et prédire au mieux la variable *label*
